// %% [markdown]
// <h1 style="color:DodgerBlue">Понятие перекрытия и перегрузка методов</h1>

// %% [markdown]
// ### Перекрытие методов в C#
//
// Перекрытие методов (или переопределение) — это процесс, при котором производный класс предоставляет новую реализацию метода, уже существующего в его базовом классе. Это позволяет изменить или расширить поведение метода в производном классе без изменения исходного метода в базовом классе. Перекрытие методов является ключевой особенностью полиморфизма в объектно-ориентированном программировании.
//
// #### Пример с классами `Vehicle`, `Car` и `Motorcycle`
//
// Давайте рассмотрим пример с классами `Vehicle`, `Car` и `Motorcycle`, где каждый из этих классов имеет метод `Drive()`, который принимает параметр `speed`.
//
// ```csharp
// // Базовый класс Vehicle с виртуальным методом Drive()
// public class Vehicle
// {
//     public virtual void Drive(int speed)
//     {
//         Console.WriteLine($"Транспорт движется {speed} km/h.");
//     }
// }
//
// // Производный класс Car, переопределяющий метод Drive()
// public class Car : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         Console.WriteLine($"Автомобиль движется {speed} km/h.");
//     }
// }
//
// // Производный класс Motorcycle, также переопределяющий метод Drive()
// public class Motorcycle : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         Console.WriteLine($"Мотоцикл движется {speed} km/h.");
//     }
// }
// ```
//
// В этом примере, метод `Drive()` в классе `Car` и `Motorcycle` переопределяет метод `Drive()` из базового класса `Vehicle`. Это означает, что при вызове метода `Drive()` на объекте типа `Car` или `Motorcycle`, будет вызвана соответствующая реализация метода в этих классах, а не в классе `Vehicle`.
//
// #### Отличие перекрытия от перегрузки методов
//
// Перегрузка методов — это процесс определения нескольких методов с одним и тем же именем, но с разным количеством или типом параметров. Например:
//
// ```csharp
// public class ExampleClass
// {
//     public void Print(int number)
//     {
//         Console.WriteLine(number);
//     }
//
//     public void Print(double number)
//     {
//         Console.WriteLine(number.ToString());
//     }
// }
// ```
//
// В этом случае, у нас есть два метода с именем `Print`, но с разным типом параметра. Это отличается от перекрытия методов, где метод в производном классе полностью заменяет метод в базовом классе.
//
// #### Вызов методов родителя
//
// Иногда в производном классе может потребоваться вызвать метод родителя. Для этого используется ключевое слово `base`. Например, если мы хотим добавить дополнительную логику в метод `Drive()` класса `Car`, сохраняя при этом оригинальное поведение метода `Drive()` из класса `Vehicle`.
//
// ```csharp
// public class Car : Vehicle
// {
//     public override void Drive(int speed)
//     {
//         base.Drive(speed); // Вызов метода Drive() из класса Vehicle
//         Console.WriteLine("Добавляем специфическое поведение автомобиля");
//     }
// }
// ```
//
// В этом примере, после вызова `base.Drive(speed)`, выполняется дополнительная логика, специфичная для класса `Car`.
//
//
// ### Перегрузка методов в C#
//
// Перегрузка методов — это способность класса определить несколько методов с одним и тем же именем, но с разным количеством или типом параметров. Это позволяет разработчикам предоставлять различные варианты выполнения одного и того же действия в зависимости от входных данных. Перегрузка методов является одной из форм выражения полиморфизма в объектно-ориентированном программировании.
//
// #### Пример с классами `Vehicle`, `Car` и `Motorcycle`
//
// Давайте рассмотрим пример, где класс `Vehicle` содержит перегруженные методы `Drive()`, которые принимают разные типы параметров.
//
// ```csharp
// public class Vehicle
// {
//     // Метод Drive(), принимающий int
//     public void Drive(int speed)
//     {
//         Console.WriteLine($"Транспорт движется {speed} km/h.");
//     }
//
//     // Метод Drive(), принимающий string
//     public void Drive(string mode)
//     {
//         Console.WriteLine($"Автомобиль движется в {mode} режиме.");
//     }
//
//     // Метод Drive(), принимающий bool
//     public void Drive(bool isManual)
//     {
//         if (isManual)
//         {
//             Console.WriteLine("Автомобиль переключает передачи вручную.");
//         }
//         else
//         {
//             Console.WriteLine("Автомобиль оснащен автоматической коробкой передач.");
//         }
//     }
// }
// ```
//
// В этом примере класс `Vehicle` определяет три метода с именем `Drive()`, каждый из которых принимает разные типы параметров: `int`, `string` и `bool`. Это позволяет вызывать разные версии метода `Drive()` в зависимости от контекста, например:
//
// ```csharp
// Vehicle myVehicle = new Vehicle();
//
// myVehicle.Drive(60); // Вызов метода Drive() с int параметром
// myVehicle.Drive("Eco"); // Вызов метода Drive() с string параметром
// myVehicle.Drive(true); // Вызов метода Drive() с bool параметром
// ```
//
// #### Отличие перегрузки от переопределения
//
// Отличие перегрузки методов от переопределения заключается в том, что перегрузка методов включает определение нескольких методов с одним именем, но с разным набором параметров, тогда как переопределение методов (или перекрытие) означает предоставление новой реализации метода в производном классе, который уже существует в базовом классе.
//
// #### Вызов методов
//
// При вызове перегруженного метода компилятор выбирает подходящую версию метода на основе типов и количества аргументов, переданных в вызове. Если типы и количество аргументов совпадают с несколькими версиями метода, компилятор выберет ту версию, которая была объявлена первой.
//
// ### Заключение
//
// Перегрузка методов в C# позволяет классам предоставлять различные варианты выполнения одного и того же действия, адаптируясь к различным условиям использования. Это мощный инструмент для создания гибких и удобных API, позволяющих клиентам класса использовать его функциональность наиболее эффективно.
//
// Перекрытие методов в C# позволяет производным классам изменять или расширять поведение методов базовых классов, что является ключевой особенностью полиморфизма. Это отличается от перегрузки методов, которая предполагает определение нескольких методов с одинаковым именем, но с разным набором параметров.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    public virtual void Drive(int speed)
    {
        Console.WriteLine($"Транспорт движется {speed} km/h.");
    }
}

// Производный класс Car, переопределяющий метод Drive()
public class Car : Vehicle
{
    public override void Drive(int speed)
    {
        Console.WriteLine($"Автомобиль движется {speed} km/h.");
    }
}

// Производный класс Motorcycle, также переопределяющий метод Drive()
public class Motorcycle : Vehicle
{
    public override void Drive(int speed)
    {
        Console.WriteLine($"Мотоцикл движется {speed} km/h.");
    }
}

// Демонстрация перекрытия методов
Console.WriteLine("=== Демонстрация перекрытия методов ===");
List<Vehicle> vehicles = new List<Vehicle>
{
    new Car(),
    new Motorcycle(),
    new Vehicle()
};

foreach (var vehicle in vehicles)
{
    vehicle.Drive(100); // Полиморфный вызов
}

// Пример с перегрузкой методов
Console.WriteLine("\n=== Демонстрация перегрузки методов ===");
public class Transport
{
    // Перегрузка метода Drive с разными параметрами
    public void Drive(int speed)
    {
        Console.WriteLine($"Транспорт движется {speed} km/h.");
    }
    
    public void Drive(string mode)
    {
        Console.WriteLine($"Транспорт движется в {mode} режиме.");
    }
    
    public void Drive(int speed, string destination)
    {
        Console.WriteLine($"Транспорт движется {speed} km/h к {destination}.");
    }
    
    public void Drive(bool isManual)
    {
        string transmission = isManual ? "ручной" : "автоматической";
        Console.WriteLine($"Транспорт с {transmission} коробкой передач.");
    }
}

Transport transport = new Transport();
transport.Drive(80);
transport.Drive("спортивный");
transport.Drive(60, "аэропорт");
transport.Drive(true);
// Out:
// === Демонстрация перекрытия методов ===
// Автомобиль движется 100 km/h.
// Мотоцикл движется 100 km/h.
// Транспорт движется 100 km/h.
//
// === Демонстрация перегрузки методов ===
// Транспорт движется 80 km/h.
// Транспорт движется в спортивный режиме.
// Транспорт движется 60 km/h к аэропорт.
// Транспорт с ручной коробкой передач.

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также используйте перекрытия и перегрузки методов.

// %%
public class Animal
{
    // Свойства с геттерами и сеттерами
    public string Name { get; set; }
    public int Age { get; set; }
    public string Color { get; set; }
    public double Weight { get; set; }
    
    // Конструктор
    public Animal(string name, int age, string color, double weight)
    {
        Name = name;
        Age = age;
        Color = color;
        Weight = weight;
    }
    
    // Виртуальный метод для демонстрации перекрытия (переопределения)
    public virtual void MakeSound()
    {
        Console.WriteLine($"{Name} издает звук.");
    }
    
    // Виртуальный метод для отображения информации
    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Животное: {Name}, Возраст: {Age}, Цвет: {Color}, Вес: {Weight}кг");
    }
    
    // Перегрузка методов - разные версии метода Eat()
    public void Eat()
    {
        Console.WriteLine($"{Name} ест.");
    }
    
    public void Eat(string food)
    {
        Console.WriteLine($"{Name} ест {food}.");
    }
    
    public void Eat(string food, double amount)
    {
        Console.WriteLine($"{Name} ест {amount}кг {food}.");
    }
    
    public void Eat(bool isHungry)
    {
        if (isHungry)
        {
            Console.WriteLine($"{Name} голоден и ищет еду.");
        }
        else
        {
            Console.WriteLine($"{Name} сыт и отдыхает.");
        }
    }
}

// Производный класс Dog
public class Dog : Animal
{
    public string Breed { get; set; }
    
    public Dog(string name, int age, string color, double weight, string breed) 
        : base(name, age, color, weight)
    {
        Breed = breed;
    }
    
    // Перекрытие (переопределение) метода MakeSound
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} ({Breed}) лает: Гав-гав!");
    }
    
    // Перекрытие (переопределение) метода DisplayInfo
    public override void DisplayInfo()
    {
        Console.WriteLine($"Собака: {Name}, Порода: {Breed}, Возраст: {Age}, Цвет: {Color}, Вес: {Weight}кг");
    }
    
    // Перегрузка методов для Dog
    public void Play()
    {
        Console.WriteLine($"{Name} играет с мячиком.");
    }
    
    public void Play(string toy)
    {
        Console.WriteLine($"{Name} играет с {toy}.");
    }
    
    public void Play(string toy, int duration)
    {
        Console.WriteLine($"{Name} играет с {toy} в течение {duration} минут.");
    }
    
    // Вызов метода базового класса с помощью base
    public void MakeBaseSound()
    {
        base.MakeSound();
    }
}

// Производный класс Cat
public class Cat : Animal
{
    public bool IsIndoor { get; set; }
    
    public Cat(string name, int age, string color, double weight, bool isIndoor) 
        : base(name, age, color, weight)
    {
        IsIndoor = isIndoor;
    }
    
    // Перекрытие (переопределение) метода MakeSound
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} мяукает: Мяу-мяу!");
    }
    
    // Перекрытие (переопределение) метода DisplayInfo
    public override void DisplayInfo()
    {
        string indoorStatus = IsIndoor ? "домашний" : "уличный";
        Console.WriteLine($"Кот: {Name}, {indoorStatus}, Возраст: {Age}, Цвет: {Color}, Вес: {Weight}кг");
    }
    
    // Перегрузка методов для Cat
    public void Sleep()
    {
        Console.WriteLine($"{Name} спит.");
    }
    
    public void Sleep(int hours)
    {
        Console.WriteLine($"{Name} спит {hours} часов.");
    }
    
    public void Sleep(bool isTired)
    {
        if (isTired)
        {
            Console.WriteLine($"{Name} устал и крепко спит.");
        }
        else
        {
            Console.WriteLine($"{Name} дремлет.");
        }
    }
}

// Производный класс Bird
public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanFly { get; set; }
    
    public Bird(string name, int age, string color, double weight, double wingspan, bool canFly) 
        : base(name, age, color, weight)
    {
        Wingspan = wingspan;
        CanFly = canFly;
    }
    
    // Перекрытие (переопределение) метода MakeSound
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} чирикает: Чик-чирик!");
    }
    
    // Перекрытие (переопределение) метода DisplayInfo
    public override void DisplayInfo()
    {
        string flyAbility = CanFly ? "летающая" : "нелетающая";
        Console.WriteLine($"Птица: {Name}, {flyAbility}, Размах крыльев: {Wingspan}см, Возраст: {Age}, Цвет: {Color}, Вес: {Weight}кг");
    }
    
    // Перегрузка методов для Bird
    public void Fly()
    {
        if (CanFly)
        {
            Console.WriteLine($"{Name} летит!");
        }
        else
        {
            Console.WriteLine($"{Name} не может летать.");
        }
    }
    
    public void Fly(int height)
    {
        if (CanFly)
        {
            Console.WriteLine($"{Name} летит на высоте {height} метров.");
        }
        else
        {
            Console.WriteLine($"{Name} не может летать.");
        }
    }
    
    public void Fly(string direction)
    {
        if (CanFly)
        {
            Console.WriteLine($"{Name} летит в направлении {direction}.");
        }
        else
        {
            Console.WriteLine($"{Name} не может летать.");
        }
    }
}

// Производный класс Fish
public class Fish : Animal
{
    public string WaterType { get; set; }
    public double SwimSpeed { get; set; }
    
    public Fish(string name, int age, string color, double weight, string waterType, double swimSpeed) 
        : base(name, age, color, weight)
    {
        WaterType = waterType;
        SwimSpeed = swimSpeed;
    }
    
    // Перекрытие (переопределение) метода MakeSound
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} издает звук: Буль-буль!");
    }
    
    // Перекрытие (переопределение) метода DisplayInfo
    public override void DisplayInfo()
    {
        Console.WriteLine($"Рыба: {Name}, Тип воды: {WaterType}, Скорость: {SwimSpeed} м/с, Возраст: {Age}, Цвет: {Color}, Вес: {Weight}кг");
    }
    
    // Перегрузка методов для Fish
    public void Swim()
    {
        Console.WriteLine($"{Name} плавает в {WaterType} воде.");
    }
    
    public void Swim(double speed)
    {
        Console.WriteLine($"{Name} плавает со скоростью {speed} м/с.");
    }
    
    public void Swim(string direction)
    {
        Console.WriteLine($"{Name} плывет в направлении {direction}.");
    }
}

// Демонстрация перекрытия и перегрузки методов
Console.WriteLine("=== Демонстрация перекрытия и перегрузки методов ===");

List<Animal> animals = new List<Animal>
{
    new Dog("Бобик", 3, "Коричневый", 25.5, "Лабрадор"),
    new Cat("Мурзик", 2, "Серый", 4.2, true),
    new Bird("Кеша", 1, "Зеленый", 0.3, 15.5, true),
    new Fish("Немо", 1, "Оранжевый", 0.2, "морская", 2.5),
    new Animal("Неизвестное животное", 1, "Разноцветный", 10.0)
};

// Демонстрация перекрытия (полиморфизм)
Console.WriteLine("\n--- Перекрытие методов (полиморфизм) ---");
foreach (var animal in animals)
{
    animal.DisplayInfo();
    animal.MakeSound();
    Console.WriteLine("---");
}

// Демонстрация перегрузки методов
Console.WriteLine("\n--- Перегрузка методов ---");

// Перегрузка метода Eat в базовом классе
Animal genericAnimal = new Animal("Животное", 2, "серый", 5.0);
genericAnimal.Eat();
genericAnimal.Eat("мясо");
genericAnimal.Eat("фрукты", 1.5);
genericAnimal.Eat(true);

Console.WriteLine();

// Перегрузка методов в производных классах
Dog dog = new Dog("Шарик", 4, "черный", 30.0, "Овчарка");
dog.Play();
dog.Play("косточка");
dog.Play("мячик", 30);

Console.WriteLine();

Cat cat = new Cat("Васька", 3, "белый", 5.0, false);
cat.Sleep();
cat.Sleep(8);
cat.Sleep(true);

Console.WriteLine();

Bird bird = new Bird("Гоша", 2, "синий", 0.4, 20.0, true);
bird.Fly();
bird.Fly(100);
bird.Fly("север");

Console.WriteLine();

Fish fish = new Fish("Дори", 2, "синий", 0.3, "морская", 3.0);
fish.Swim();
fish.Swim(2.8);
fish.Swim("восток");

// Демонстрация вызова метода базового класса
Console.WriteLine("\n--- Вызов метода базового класса ---");
dog.MakeBaseSound();
// Out:
// === Демонстрация перекрытия и перегрузки методов ===
//
// --- Перекрытие методов (полиморфизм) ---
// Собака: Бобик, Порода: Лабрадор, Возраст: 3, Цвет: Коричневый, Вес: 25.5кг
// Бобик (Лабрадор) лает: Гав-гав!
// ---
// Кот: Мурзик, домашний, Возраст: 2, Цвет: Серый, Вес: 4.2кг
// Мурзик мяукает: Мяу-мяу!
// ---
// Птица: Кеша, летающая, Размах крыльев: 15.5см, Возраст: 1, Цвет: Зеленый, Вес: 0.3кг
// Кеша чирикает: Чик-чирик!
// ---
// Рыба: Немо, Тип воды: морская, Скорость: 2.5 м/с, Возраст: 1, Цвет: Оранжевый, Вес: 0.2кг
// Немо издает звук: Буль-буль!
// ---
// Животное: Неизвестное животное, Возраст: 1, Цвет: Разноцветный, Вес: 10кг
// Неизвестное животное издает звук.
// ---
//
// --- Перегрузка методов ---
// Животное ест.
// Животное ест мясо.
// Животное ест 1.5кг фрукты.
// Животное голоден и ищет еду.
//
// Шарик играет с мячиком.
// Шарик играет с косточка.
// Шарик играет с мячик в течение 30 минут.
//
// Васька спит.
// Васька спит 8 часов.
// Васька устал и крепко спит.
//
// Гоша летит!
// Гоша летит на высоте 100 метров.
// Гоша летит в направлении север.
//
// Дори плавает в морская воде.
// Дори плавает со скоростью 2.8 м/с.
// Дори плывет в направлении восток.
//
// --- Вызов метода базового класса ---
// Шарик издает звук.
